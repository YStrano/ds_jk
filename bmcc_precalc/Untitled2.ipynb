# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'planets',
#  'tips',
#  'titanic']

# %%
anscombe = sns.load_dataset('anscombe')
iris = sns.load_dataset('iris')

# %%
import pandas as pd

# %%
anscombe.to_csv('data/anscombe.csv')

# %%
iris.to_csv('data/iris.csv')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.distplot?

# %%
iris = sns.load_dataset('iris')

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.distplot(iris.sepal_width, kde = True, kde_kws=dict(cumulative=True), hist_kws=dict(cumulative=True))

# %%
import statsmodels.api as sm
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
sm.ProbPlot?
x = np.arange(0, len(iris.sepal_length))

# %%
plt.hist(iris.sepal_length,  cumulative = -1)
plt.plot(x, iris.sepal_length.sort_values())

# %%
iris.sepal_length.sort_values()
# Out:
# 13     4.3
# 42     4.4
# 38     4.4
# 8      4.4
# 41     4.5
# 22     4.6
# 3      4.6
# 6      4.6
# 47     4.6
# 2      4.7
# 29     4.7
# 12     4.8
# 45     4.8
# 24     4.8
# 11     4.8
# 30     4.8
# 57     4.9
# 106    4.9
# 34     4.9
# 9      4.9
# 37     4.9
# 1      4.9
# 40     5.0
# 26     5.0
# 49     5.0
# 35     5.0
# 43     5.0
# 60     5.0
# 7      5.0
# 93     5.0
#       ...
# 58     6.6
# 75     6.6
# 86     6.7
# 140    6.7
# 108    6.7
# 77     6.7
# 65     6.7
# 144    6.7
# 145    6.7
# 124    6.7
# 143    6.8
# 76     6.8
# 112    6.8
# 139    6.9
# 141    6.9
# 52     6.9
# 120    6.9
# 50     7.0
# 102    7.1
# 129    7.2
# 125    7.2
# 109    7.2
# 107    7.3
# 130    7.4
# 105    7.6
# 122    7.7
# 118    7.7
# 117    7.7
# 135    7.7
# 131    7.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris.plot?
